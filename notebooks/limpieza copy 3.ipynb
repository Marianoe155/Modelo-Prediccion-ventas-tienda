# %% [markdown]
# Para la presentación de 30 minutos, los 3 insights de negocio clave son
# 1. El precio del producto es el factor más determinante de las ventas (45% de importancia)
# 2. El tipo de tienda importa tanto como el precio: los supermercados grandes venden significativamente más
# 3. La antigüedad de la tienda importa: las tiendas consolidadas tienen mejor performance

# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python313\python.exe
